# %%
import pandas as pd

# %%
data=pd.read_csv('../data/vehicles.csv')
print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  str
#  2   region        426880 non-null  str
#  3   region_url    426880 non-null  str
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  str
#  7   model         421603 non-null  str
#  8   condition     252776 non-null  str
#  9   cylinders     249202 non-null  str
#  10  fuel          423867 non-null  str
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  str
#  13  transmission  424324 non-null  str
#  14  VIN           265838 non-null  str
#  15  drive         296313 non-null  str
#  16  size          120519 non-null  str
#  17  type          334022 non-null  str
# ...

# %%
data
# Out:
#                 id                                                url  \
# 0       7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1       7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2       7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3       7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4       7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# ...            ...                                                ...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#                         region                         region_url  price  \
# ...

# %%
data=data.drop(columns=["id","url","region_url","lat","long","paint_color","image_url","description","VIN","posting_date","region","county"])

# %%
pd.set_option('display.max_columns', None)
data.tail(5)
# Out:
#         price    year manufacturer                     model condition  \
# 426875  23590  2019.0       nissan         maxima s sedan 4d      good
# 426876  30590  2020.0        volvo  s60 t5 momentum sedan 4d      good
# 426877  34990  2020.0     cadillac          xt4 sport suv 4d      good
# 426878  28990  2018.0        lexus           es 350 sedan 4d      good
# 426879  30590  2019.0          bmw  4 series 430i gran coupe      good
#
#           cylinders    fuel  odometer title_status transmission drive size  \
# 426875  6 cylinders     gas   32226.0        clean        other   fwd  NaN
# 426876          NaN     gas   12029.0        clean        other   fwd  NaN
# 426877          NaN  diesel    4174.0        clean        other   NaN  NaN
# 426878  6 cylinders     gas   30112.0        clean        other   fwd  NaN
# 426879          NaN     gas   22716.0        clean        other   rwd  NaN
#
#              type state
# 426875      sedan    wy
# 426876      sedan    wy
# ...

# %%
data.info()
data["transmission"].unique()
data["state"].unique()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         426880 non-null  int64
#  1   year          425675 non-null  float64
#  2   manufacturer  409234 non-null  str
#  3   model         421603 non-null  str
#  4   condition     252776 non-null  str
#  5   cylinders     249202 non-null  str
#  6   fuel          423867 non-null  str
#  7   odometer      422480 non-null  float64
#  8   title_status  418638 non-null  str
#  9   transmission  424324 non-null  str
#  10  drive         296313 non-null  str
#  11  size          120519 non-null  str
#  12  type          334022 non-null  str
#  13  state         426880 non-null  str
# dtypes: float64(2), int64(1), str(11)
# memory usage: 45.6 MB
# <StringArray>
# ['az', 'ar', 'fl', 'ma', 'nc', 'ny', 'or', 'pa', 'tx', 'wa', 'wi', 'al', 'ak',
# ...

# %%
#data.tail().sort_values(by="model")
boolean= not data["model"].is_unique
boolean
# Out:
# True

# %%
mask_man = data[["manufacturer", "model"]].dropna()
model2man=dict(zip(mask_man["model"], mask_man["manufacturer"]))
data["manufacturer"]=data["manufacturer"].fillna(data["model"].map(model2man))
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         426880 non-null  int64
#  1   year          425675 non-null  float64
#  2   manufacturer  410002 non-null  str
#  3   model         421603 non-null  str
#  4   condition     252776 non-null  str
#  5   cylinders     249202 non-null  str
#  6   fuel          423867 non-null  str
#  7   odometer      422480 non-null  float64
#  8   title_status  418638 non-null  str
#  9   transmission  424324 non-null  str
#  10  drive         296313 non-null  str
#  11  size          120519 non-null  str
#  12  type          334022 non-null  str
#  13  state         426880 non-null  str
# dtypes: float64(2), int64(1), str(11)
# memory usage: 45.6 MB

# %%
data.duplicated().any()
data=data.drop_duplicates()
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 298865 entries, 0 to 426879
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         298865 non-null  int64
#  1   year          297996 non-null  float64
#  2   manufacturer  286407 non-null  str
#  3   model         294619 non-null  str
#  4   condition     185416 non-null  str
#  5   cylinders     182847 non-null  str
#  6   fuel          296984 non-null  str
#  7   odometer      296202 non-null  float64
#  8   title_status  294161 non-null  str
#  9   transmission  297262 non-null  str
#  10  drive         210683 non-null  str
#  11  size          94675 non-null   str
#  12  type          230068 non-null  str
#  13  state         298865 non-null  str
# dtypes: float64(2), int64(1), str(11)
# memory usage: 34.2 MB

# %%
mask_size=data[["size", "model"]].dropna()
size_dict=dict(zip(mask_size["model"], mask_size["size"]))
data["size"]=data["size"].fillna(data["model"].map(size_dict))

data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 298865 entries, 0 to 426879
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         298865 non-null  int64
#  1   year          297996 non-null  float64
#  2   manufacturer  286407 non-null  str
#  3   model         294619 non-null  str
#  4   condition     185416 non-null  str
#  5   cylinders     182847 non-null  str
#  6   fuel          296984 non-null  str
#  7   odometer      296202 non-null  float64
#  8   title_status  294161 non-null  str
#  9   transmission  297262 non-null  str
#  10  drive         210683 non-null  str
#  11  size          242947 non-null  str
#  12  type          230068 non-null  str
#  13  state         298865 non-null  str
# dtypes: float64(2), int64(1), str(11)
# memory usage: 34.2 MB

# %%
mask_size=data[["model", "drive"]].dropna()
size_dict=dict(zip(mask_size["model"], mask_size["drive"]))
data["drive"]=data["drive"].fillna(data["model"].map(size_dict))

data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 298865 entries, 0 to 426879
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         298865 non-null  int64
#  1   year          297996 non-null  float64
#  2   manufacturer  286407 non-null  str
#  3   model         294619 non-null  str
#  4   condition     185416 non-null  str
#  5   cylinders     182847 non-null  str
#  6   fuel          296984 non-null  str
#  7   odometer      296202 non-null  float64
#  8   title_status  294161 non-null  str
#  9   transmission  297262 non-null  str
#  10  drive         282213 non-null  str
#  11  size          242947 non-null  str
#  12  type          230068 non-null  str
#  13  state         298865 non-null  str
# dtypes: float64(2), int64(1), str(11)
# memory usage: 34.2 MB

# %%
mask_size=data[["model", "type"]].dropna()
size_dict=dict(zip(mask_size["model"], mask_size["type"]))
data["type"]=data["type"].fillna(data["model"].map(size_dict))

data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 298865 entries, 0 to 426879
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         298865 non-null  int64
#  1   year          297996 non-null  float64
#  2   manufacturer  286407 non-null  str
#  3   model         294619 non-null  str
#  4   condition     185416 non-null  str
#  5   cylinders     182847 non-null  str
#  6   fuel          296984 non-null  str
#  7   odometer      296202 non-null  float64
#  8   title_status  294161 non-null  str
#  9   transmission  297262 non-null  str
#  10  drive         282213 non-null  str
#  11  size          242947 non-null  str
#  12  type          289765 non-null  str
#  13  state         298865 non-null  str
# dtypes: float64(2), int64(1), str(11)
# memory usage: 34.2 MB

# %%
mask_size = data[["model", "cylinders"]].dropna()
size_dict = dict(zip(mask_size["model"], mask_size["cylinders"]))
data["cylinders"] = data["cylinders"].fillna(data["model"].map(size_dict))

data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 298865 entries, 0 to 426879
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         298865 non-null  int64
#  1   year          297996 non-null  float64
#  2   manufacturer  286407 non-null  str
#  3   model         294619 non-null  str
#  4   condition     185416 non-null  str
#  5   cylinders     273027 non-null  str
#  6   fuel          296984 non-null  str
#  7   odometer      296202 non-null  float64
#  8   title_status  294161 non-null  str
#  9   transmission  297262 non-null  str
#  10  drive         282213 non-null  str
#  11  size          242947 non-null  str
#  12  type          289765 non-null  str
#  13  state         298865 non-null  str
# dtypes: float64(2), int64(1), str(11)
# memory usage: 34.2 MB

# %%
mask_size = data[["model", "condition"]].dropna()
size_dict = dict(zip(mask_size["model"], mask_size["condition"]))
data["condition"] = data["condition"].fillna(data["model"].map(size_dict))

data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 298865 entries, 0 to 426879
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         298865 non-null  int64
#  1   year          297996 non-null  float64
#  2   manufacturer  286407 non-null  str
#  3   model         294619 non-null  str
#  4   condition     282029 non-null  str
#  5   cylinders     273027 non-null  str
#  6   fuel          296984 non-null  str
#  7   odometer      296202 non-null  float64
#  8   title_status  294161 non-null  str
#  9   transmission  297262 non-null  str
#  10  drive         282213 non-null  str
#  11  size          242947 non-null  str
#  12  type          289765 non-null  str
#  13  state         298865 non-null  str
# dtypes: float64(2), int64(1), str(11)
# memory usage: 34.2 MB

# %%
print(data["manufacturer"].nunique())
print(data["model"].nunique())
# Out:
# 42
# 29667

# %%
#we are going to use one-hot-encoding technique for manufacturer and frequency-encoding for model
data=pd.get_dummies(data,columns=["manufacturer"])
data.loc[2000,data.columns.str.startswith("manufacturer")]
frequency=data["model"].value_counts(normalize=True)
data['model_frequency']=data["model"].map(frequency)
data.tail(3)
# Out:
#         price    year                     model condition    cylinders  \
# 426877  34990  2020.0          xt4 sport suv 4d      good          NaN
# 426878  28990  2018.0           es 350 sedan 4d      good  6 cylinders
# 426879  30590  2019.0  4 series 430i gran coupe      good          NaN
#
#           fuel  odometer title_status transmission drive size       type  \
# 426877  diesel    4174.0        clean        other   fwd  NaN  hatchback
# 426878     gas   30112.0        clean        other   fwd  NaN      sedan
# 426879     gas   22716.0        clean        other   rwd  NaN      coupe
#
#        state  manufacturer_acura  manufacturer_alfa-romeo  \
# 426877    wy               False                    False
# 426878    wy               False                    False
# 426879    wy               False                    False
#
#         manufacturer_aston-martin  manufacturer_audi  manufacturer_bmw  \
# 426877                      False              False             False
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 298865 entries, 0 to 426879
# Data columns (total 56 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   price                         298865 non-null  int64
#  1   year                          297996 non-null  float64
#  2   model                         294619 non-null  str
#  3   condition                     282029 non-null  str
#  4   cylinders                     273027 non-null  str
#  5   fuel                          296984 non-null  str
#  6   odometer                      296202 non-null  float64
#  7   title_status                  294161 non-null  str
#  8   transmission                  297262 non-null  str
#  9   drive                         282213 non-null  str
#  10  size                          242947 non-null  str
#  11  type                          289765 non-null  str
#  12  state                         298865 non-null  str
# ...

# %%
#one hot encoding for state

data=pd.get_dummies(data,columns=["state"])

#making age column
data["age"]=2026-data["year"]
data=data.drop(columns=["model","year"])

# %%
data=pd.get_dummies(data,columns=["transmission"])
for i, col in enumerate(data.columns):
    print(i, col,data[col].dtype)
# Out:
# 0 price int64
# 1 condition str
# 2 cylinders str
# 3 fuel str
# 4 odometer float64
# 5 title_status str
# 6 drive str
# 7 size str
# 8 type str
# 9 manufacturer_acura bool
# 10 manufacturer_alfa-romeo bool
# 11 manufacturer_aston-martin bool
# 12 manufacturer_audi bool
# 13 manufacturer_bmw bool
# 14 manufacturer_buick bool
# 15 manufacturer_cadillac bool
# 16 manufacturer_chevrolet bool
# 17 manufacturer_chrysler bool
# 18 manufacturer_datsun bool
# 19 manufacturer_dodge bool
# 20 manufacturer_ferrari bool
# 21 manufacturer_fiat bool
# 22 manufacturer_ford bool
# 23 manufacturer_gmc bool
# 24 manufacturer_harley-davidson bool
# 25 manufacturer_honda bool
# 26 manufacturer_hyundai bool
# 27 manufacturer_infiniti bool
# 28 manufacturer_jaguar bool
# 29 manufacturer_jeep bool
# 30 manufacturer_kia bool
# 31 manufacturer_land rover bool
# 32 manufacturer_lexus bool
# 33 manufacturer_lincoln bool
# 34 manufacturer_mazda bool
# 35 manufacturer_mercedes-benz bool
# ...

# %%
data["size"].unique()
data["cylinders"].unique()

data=data[data["cylinders"]!='other']
data["cylinders"]=data["cylinders"].str.replace("cylinders","")
data["cylinders"]=pd.to_numeric(data["cylinders"],errors="coerce")

data["cylinders"].value_counts()
# Out:
# cylinders
# 6.0     97005
# 4.0     93030
# 8.0     76385
# 5.0      2295
# 3.0      1188
# 10.0     1159
# 12.0      193
# Name: count, dtype: int64

# %%
for i, col in enumerate(data.columns):
    print(i, col,data[col].dtype)
# Out:
# 0 price int64
# 1 condition str
# 2 cylinders float64
# 3 fuel str
# 4 odometer float64
# 5 title_status str
# 6 drive str
# 7 size str
# 8 type str
# 9 manufacturer_acura bool
# 10 manufacturer_alfa-romeo bool
# 11 manufacturer_aston-martin bool
# 12 manufacturer_audi bool
# 13 manufacturer_bmw bool
# 14 manufacturer_buick bool
# 15 manufacturer_cadillac bool
# 16 manufacturer_chevrolet bool
# 17 manufacturer_chrysler bool
# 18 manufacturer_datsun bool
# 19 manufacturer_dodge bool
# 20 manufacturer_ferrari bool
# 21 manufacturer_fiat bool
# 22 manufacturer_ford bool
# 23 manufacturer_gmc bool
# 24 manufacturer_harley-davidson bool
# 25 manufacturer_honda bool
# 26 manufacturer_hyundai bool
# 27 manufacturer_infiniti bool
# 28 manufacturer_jaguar bool
# 29 manufacturer_jeep bool
# 30 manufacturer_kia bool
# 31 manufacturer_land rover bool
# 32 manufacturer_lexus bool
# 33 manufacturer_lincoln bool
# 34 manufacturer_mazda bool
# 35 manufacturer_mercedes-benz bool
# ...

# %%
data["condition"].unique()
data=pd.get_dummies(data,columns=["condition"])

# %%
data["drive"].unique()
data=pd.get_dummies(data,columns=["drive"])

# %%
data["type"].unique()
data=pd.get_dummies(data,columns=["type"])

# %%
data=pd.get_dummies(data,columns=["size"])

# %%
data["title_status"].unique()
data=pd.get_dummies(data,columns=["title_status"])

# %%
data["fuel"].unique()
data=pd.get_dummies(data,columns=["fuel"])

# %%
data=data.dropna()

# %%
for i, col in enumerate(data.columns):
    print(i,col,data[col].dtype, data[col].isna().sum())
data.shape
# Out:
# 0 price int64 0
# 1 cylinders float64 0
# 2 odometer float64 0
# 3 manufacturer_acura bool 0
# 4 manufacturer_alfa-romeo bool 0
# 5 manufacturer_aston-martin bool 0
# 6 manufacturer_audi bool 0
# 7 manufacturer_bmw bool 0
# 8 manufacturer_buick bool 0
# 9 manufacturer_cadillac bool 0
# 10 manufacturer_chevrolet bool 0
# 11 manufacturer_chrysler bool 0
# 12 manufacturer_datsun bool 0
# 13 manufacturer_dodge bool 0
# 14 manufacturer_ferrari bool 0
# 15 manufacturer_fiat bool 0
# 16 manufacturer_ford bool 0
# 17 manufacturer_gmc bool 0
# 18 manufacturer_harley-davidson bool 0
# 19 manufacturer_honda bool 0
# 20 manufacturer_hyundai bool 0
# 21 manufacturer_infiniti bool 0
# 22 manufacturer_jaguar bool 0
# 23 manufacturer_jeep bool 0
# 24 manufacturer_kia bool 0
# 25 manufacturer_land rover bool 0
# 26 manufacturer_lexus bool 0
# 27 manufacturer_lincoln bool 0
# 28 manufacturer_mazda bool 0
# 29 manufacturer_mercedes-benz bool 0
# 30 manufacturer_mercury bool 0
# ...

# %%
data.to_csv(path_or_buf='../data/vehicles_cleaned.csv')
